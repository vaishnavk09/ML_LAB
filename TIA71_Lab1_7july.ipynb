# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavk09/ML_LAB/blob/main/TIA71_Lab1_7july.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=5
b=5
name='vaishnav'
print(a+b,name)
# Out:
# 10 vaishnav

# %%
mylist=[1,2,3,4]
mytuple=(21,112,21)
mydict={12:'vaishnav',13:'pratik',14:'manodnya'}
print(mylist,mytuple,mydict)
# Out:
# [1, 2, 3, 4] (21, 112, 21) {12: 'vaishnav', 13: 'pratik', 14: 'manodnya'}

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
def greet(name):
  return "hello " +name
greet('vaishnav')
# Out:
# 'hello vaishnav'

# %%
import numpy as np
a=np.array([98,99,89])
print(a)

b=np.sum(a)
print(b)
# Out:
# [98 99 89]
# 286

# %%
import pandas as pd
data= {'name':["vaishnav","pratik"],'age':[20,19]}
df=pd.DataFrame(data)
print(df)

# a=pd.get_dummies(df)
# print(a)
# Out:
#    age  name_pratik  name_vaishnav
# 0   20        False           True
# 1   19         True          False

# %%
import matplotlib.pyplot as plt
plt.plot([13,12,21,10],[10,50,55,20])
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('graph 1')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import csv as csv

# %%
dataset=pd.read_csv('/content/student-scores - student-scores.csv')

# %%
dataset.describe()
# Out:
#                 id  absence_days  weekly_self_study_hours   math_score  \
# count  2000.000000   2000.000000              2000.000000  2000.000000
# mean   1000.500000      3.665500                17.755500    83.452000
# std     577.494589      2.629271                12.129604    13.224906
# min       1.000000      0.000000                 0.000000    40.000000
# 25%     500.750000      2.000000                 5.000000    77.000000
# 50%    1000.500000      3.000000                18.000000    87.000000
# 75%    1500.250000      5.000000                28.000000    93.000000
# max    2000.000000     10.000000                50.000000   100.000000
#
#        history_score  physics_score  chemistry_score  biology_score  \
# count    2000.000000    2000.000000      2000.000000     2000.00000
# mean       80.332000      81.336500        79.995000       79.58150
# std        12.736046      12.539453        12.777895       13.72219
# ...

# %%
dataset.count()
# Out:
# id                            2000
# first_name                    2000
# last_name                     2000
# email                         2000
# gender                        2000
# part_time_job                 2000
# absence_days                  2000
# extracurricular_activities    2000
# weekly_self_study_hours       2000
# career_aspiration             2000
# math_score                    2000
# history_score                 2000
# physics_score                 2000
# chemistry_score               2000
# biology_score                 2000
# english_score                 2000
# geography_score               2000
# dtype: int64

# %%
dataset.shape
# Out:
# (2000, 17)

# %%
dataset.head(6)
# Out:
#    id first_name last_name                                  email  gender  \
# 0   1       Paul     Casey         paul.casey.1@gslingacademy.com    male
# 1   2   Danielle  Sandoval  danielle.sandoval.2@gslingacademy.com  female
# 2   3       Tina   Andrews       tina.andrews.3@gslingacademy.com  female
# 3   4       Tara     Clark         tara.clark.4@gslingacademy.com  female
# 4   5    Anthony    Campos     anthony.campos.5@gslingacademy.com    male
# 5   6      Kelly      Wade         kelly.wade.6@gslingacademy.com  female
#
#    part_time_job  absence_days  extracurricular_activities  \
# 0          False             3                       False
# 1          False             2                       False
# 2          False             9                        True
# 3          False             5                       False
# 4          False             5                       False
# 5          False             2                       False
#
# ...

# %%
dataset.notnull()
# Out:
#         id  first_name  last_name  email  gender  part_time_job  absence_days  \
# 0     True        True       True   True    True           True          True
# 1     True        True       True   True    True           True          True
# 2     True        True       True   True    True           True          True
# 3     True        True       True   True    True           True          True
# 4     True        True       True   True    True           True          True
# ...    ...         ...        ...    ...     ...            ...           ...
# 1995  True        True       True   True    True           True          True
# 1996  True        True       True   True    True           True          True
# 1997  True        True       True   True    True           True          True
# 1998  True        True       True   True    True           True          True
# 1999  True        True       True   True    True           True          True
#
# ...

# %%
dataset.tail()
# Out:
#         id first_name last_name                                    email  \
# 1995  1996       Alan  Reynolds     alan.reynolds.1996@gslingacademy.com
# 1996  1997     Thomas   Gilbert    thomas.gilbert.1997@gslingacademy.com
# 1997  1998    Madison     Cross     madison.cross.1998@gslingacademy.com
# 1998  1999   Brittany   Compton  brittany.compton.1999@gslingacademy.com
# 1999  2000    Natalie     Smith     natalie.smith.2000@gslingacademy.com
#
#       gender  part_time_job  absence_days  extracurricular_activities  \
# 1995    male          False             2                       False
# 1996    male          False             2                       False
# 1997  female          False             5                       False
# 1998  female           True            10                        True
# 1999  female          False             5                       False
#
#       weekly_self_study_hours      career_aspiration  math_score  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          2000 non-null   int64
#  1   first_name                  2000 non-null   object
#  2   last_name                   2000 non-null   object
#  3   email                       2000 non-null   object
#  4   gender                      2000 non-null   object
#  5   part_time_job               2000 non-null   bool
#  6   absence_days                2000 non-null   int64
#  7   extracurricular_activities  2000 non-null   bool
#  8   weekly_self_study_hours     2000 non-null   int64
#  9   career_aspiration           2000 non-null   object
#  10  math_score                  2000 non-null   int64
#  11  history_score               2000 non-null   int64
#  12  physics_score               2000 non-null   int64
# ...

# %%
dataset.drop(columns=['email'])
# Out:
#         id first_name last_name  gender  part_time_job  absence_days  \
# 0        1       Paul     Casey    male          False             3
# 1        2   Danielle  Sandoval  female          False             2
# 2        3       Tina   Andrews  female          False             9
# 3        4       Tara     Clark  female          False             5
# 4        5    Anthony    Campos    male          False             5
# ...    ...        ...       ...     ...            ...           ...
# 1995  1996       Alan  Reynolds    male          False             2
# 1996  1997     Thomas   Gilbert    male          False             2
# 1997  1998    Madison     Cross  female          False             5
# 1998  1999   Brittany   Compton  female           True            10
# 1999  2000    Natalie     Smith  female          False             5
#
#       extracurricular_activities  weekly_self_study_hours  \
# 0                          False                       27
# ...

# %%
dataset.rename(columns={'part_time_job':'part_time'}, inplace=True)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          2000 non-null   int64
#  1   first_name                  2000 non-null   object
#  2   last_name                   2000 non-null   object
#  3   email                       2000 non-null   object
#  4   gender                      2000 non-null   object
#  5   part_time                   2000 non-null   bool
#  6   absence_days                2000 non-null   int64
#  7   extracurricular_activities  2000 non-null   bool
#  8   weekly_self_study_hours     2000 non-null   int64
#  9   career_aspiration           2000 non-null   object
#  10  math_score                  2000 non-null   int64
#  11  history_score               2000 non-null   int64
#  12  physics_score               2000 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split

# %%
le=LabelEncoder()
le.fit_transform(dataset['gender'])
le.fit_transform(dataset['part_time'])
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
dataset.head()
# Out:
#    id first_name last_name                                  email  gender  \
# 0   1       Paul     Casey         paul.casey.1@gslingacademy.com    male
# 1   2   Danielle  Sandoval  danielle.sandoval.2@gslingacademy.com  female
# 2   3       Tina   Andrews       tina.andrews.3@gslingacademy.com  female
# 3   4       Tara     Clark         tara.clark.4@gslingacademy.com  female
# 4   5    Anthony    Campos     anthony.campos.5@gslingacademy.com    male
#
#    part_time  absence_days  extracurricular_activities  \
# 0      False             3                       False
# 1      False             2                       False
# 2      False             9                        True
# 3      False             5                       False
# 4      False             5                       False
#
#    weekly_self_study_hours   career_aspiration  math_score  history_score  \
# 0                       27              Lawyer          73             81
# ...

# %%
plt.plot(dataset['math_score'],dataset['history_score'])
plt.xlabel('math_score')
plt.ylabel('history_score')
plt.title('subject scores')

plt.show()

# %%
plt.plot(dataset['math_score'],dataset['history_score'])
plt.xlabel('math_score')
plt.style('figure.figsize':(10,10))
plt.ylabel('history_score')
plt.title('subject scores')

plt.show()
# Out:
#   File "/tmp/ipython-input-65-2486126044.py", line 3
#     plt.style('figure.figsize':(10,10))
#                               ^
# SyntaxError: invalid syntax
